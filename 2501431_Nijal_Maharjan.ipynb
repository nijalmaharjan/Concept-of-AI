# %%
#pandas library to work with data in table form
#matplotlib to create graphs and charts
#numpy for numerical calculations and array operations
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Problem - 1A - Single Year HDI Exploration (Latest Year: 2022)

# %%
# encoding="latin1" is used to read special characters in the file
df=pd.read_csv("Human_Development_Index_Dataset.csv",encoding="latin1")
df.head()
# Out:
#    Unnamed: 0 iso3      country  year    hdi  life_expectancy  pop_millions  \
# 0           1  AFG  Afghanistan  1990  0.284           45.967     10.694796
# 1           2  AFG  Afghanistan  1991  0.292           46.663     10.745167
# 2           3  AFG  Afghanistan  1992  0.299           47.596     12.057433
# 3           4  AFG  Afghanistan  1993  0.307           51.466     14.003760
# 4           5  AFG  Afghanistan  1994  0.300           51.495     15.455554
#
#    hdi_f  hdi_m  life_expec_f  ...  gender_development  gender_inequality  \
# 0    NaN    NaN        48.397  ...                 NaN                NaN
# 1    NaN    NaN        49.144  ...                 NaN                NaN
# 2    NaN    NaN        50.320  ...                 NaN                NaN
# 3    NaN    NaN        52.739  ...                 NaN                NaN
# 4    NaN    NaN        53.544  ...                 NaN                NaN
#
#    secondary_education_f_%  secondary_education_m_%  seats_in_parliament_f_%  \
# 0                 1.107733                 7.899011                      NaN
# 1                 1.221396                 8.137953                      NaN
# 2                 1.335059                 8.376896                      NaN
# 3                 1.448722                 8.615838                      NaN
# 4                 1.562385                 8.854780                      NaN
#
#    seats_in_parliament_m_%  labour_participation_f_%  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
#
#    labour_participation_m_%  co2_emission_tons  mat_footprint_percap_tons
# 0                       NaN           0.189279                     2.1809
# 1                       NaN           0.178155                     2.5264
# 2                       NaN           0.122920                     2.6421
# 3                       NaN           0.106179                     2.3022
# 4                       NaN           0.094063                     1.8948
#
# [5 rows x 30 columns]

# %%
# Get all unique values from the year column and sort in ascending order
unique_years = df['year'].unique()
unique_years = sorted(unique_years)
unique_years
# Out:
# [np.int64(1990),
#  np.int64(1991),
#  np.int64(1992),
#  np.int64(1993),
#  np.int64(1994),
#  np.int64(1995),
#  np.int64(1996),
#  np.int64(1997),
#  np.int64(1998),
#  np.int64(1999),
#  np.int64(2000),
#  np.int64(2001),
#  np.int64(2002),
#  np.int64(2003),
#  np.int64(2004),
#  np.int64(2005),
#  np.int64(2006),
#  np.int64(2007),
#  np.int64(2008),
#  np.int64(2009),
#  np.int64(2010),
#  np.int64(2011),
#  np.int64(2012),
#  np.int64(2013),
#  np.int64(2014),
#  np.int64(2015),
#  np.int64(2016),
#  np.int64(2017),
#  np.int64(2018),
#  np.int64(2019),
#  np.int64(2020),
#  np.int64(2021),
#  np.int64(2022)]

# %%
# Filter the dataset to include only rows where the year is 2022 and display num of rows and column
hdi_2022_df = df[df['year'] == 2022]
hdi_2022_df.shape
hdi_2022_df.head()
# Out:
#      Unnamed: 0 iso3      country  year    hdi  life_expectancy  pop_millions  \
# 32           33  AFG  Afghanistan  2022  0.462           62.879     41.128771
# 65           66  ALB      Albania  2022  0.789           76.833      2.842321
# 98           99  DZA      Algeria  2022  0.745           77.129     44.903225
# 131         132  AND      Andorra  2022  0.884           83.552      0.079824
# 164         165  AGO       Angola  2022  0.591           61.929     35.588987
#
#         hdi_f     hdi_m  life_expec_f  ...  gender_development  \
# 32   0.332443  0.534145        66.213  ...               0.622
# 65   0.780277  0.798432        79.472  ...               0.977
# 98   0.681844  0.773800        78.457  ...               0.881
# 131       NaN       NaN        85.838  ...                 NaN
# 164  0.560890  0.619680        64.541  ...               0.905
#
#      gender_inequality  secondary_education_f_%  secondary_education_m_%  \
# 32               0.665                 7.042050                24.077040
# 65               0.116                82.249185                86.476634
# 98               0.460                42.910456                46.815170
# 131                NaN                81.718277                84.599998
# 164              0.520                21.339865                37.411946
#
#      seats_in_parliament_f_%  seats_in_parliament_m_%  \
# 32                 27.215190                72.784810
# 65                 35.714286                64.285714
# 98                  7.005254                92.994746
# 131                46.428571                53.571429
# 164                33.636364                66.363636
#
#      labour_participation_f_%  labour_participation_m_%  co2_emission_tons  \
# 32                      23.33                     77.09           0.306318
# 65                      56.08                     69.91           1.717758
# 98                      17.57                     65.53           4.079540
# 131                       NaN                       NaN           4.593593
# 164                     74.73                     78.16           0.507359
#
#      mat_footprint_percap_tons
# 32                      1.1809
# 65                     11.7367
# 98                      8.7199
# 131                        NaN
# 164                     3.6568
#
# [5 rows x 30 columns]

# %%
hdi_2022_df.head(10)
# Out:
#      Unnamed: 0 iso3              country  year    hdi  life_expectancy  \
# 32           33  AFG          Afghanistan  2022  0.462           62.879
# 65           66  ALB              Albania  2022  0.789           76.833
# 98           99  DZA              Algeria  2022  0.745           77.129
# 131         132  AND              Andorra  2022  0.884           83.552
# 164         165  AGO               Angola  2022  0.591           61.929
# 197         198  ATG  Antigua and Barbuda  2022  0.826           79.236
# 230         231  ARG            Argentina  2022  0.849           76.064
# 263         264  ARM              Armenia  2022  0.786           73.372
# 296         297  AUS            Australia  2022  0.946           83.579
# 329         330  AUT              Austria  2022  0.926           82.412
#
#      pop_millions     hdi_f     hdi_m  life_expec_f  ...  gender_development  \
# 32      41.128771  0.332443  0.534145        66.213  ...               0.622
# 65       2.842321  0.780277  0.798432        79.472  ...               0.977
# 98      44.903225  0.681844  0.773800        78.457  ...               0.881
# 131      0.079824       NaN       NaN        85.838  ...                 NaN
# 164     35.588987  0.560890  0.619680        64.541  ...               0.905
# 197      0.093763       NaN       NaN        81.645  ...                 NaN
# 230     45.510318  0.841405  0.845473        79.277  ...               0.995
# 263      2.780469  0.795110  0.774942        78.447  ...               1.026
# 296     26.177414  0.934602  0.955941        85.453  ...               0.978
# 329      8.939617  0.911592  0.937756        84.600  ...               0.972
#
#      gender_inequality  secondary_education_f_%  secondary_education_m_%  \
# 32               0.665                 7.042050                24.077040
# 65               0.116                82.249185                86.476634
# 98               0.460                42.910456                46.815170
# 131                NaN                81.718277                84.599998
# 164              0.520                21.339865                37.411946
# 197                NaN                      NaN                      NaN
# 230              0.292                73.591541                71.648085
# 263              0.198                96.001381                97.050957
# 296              0.063                94.580063                94.430069
# 329              0.048               100.000000               100.000000
#
#      seats_in_parliament_f_%  seats_in_parliament_m_%  \
# 32                 27.215190                72.784810
# 65                 35.714286                64.285714
# 98                  7.005254                92.994746
# 131                46.428571                53.571429
# 164                33.636364                66.363636
# 197                31.428571                68.571429
# 230                44.376900                55.623100
# 263                35.514019                64.485981
# 296                44.493392                55.506608
# 329                40.983607                59.016393
#
#      labour_participation_f_%  labour_participation_m_%  co2_emission_tons  \
# 32                      23.33                     77.09           0.306318
# 65                      56.08                     69.91           1.717758
# 98                      17.57                     65.53           4.079540
# 131                       NaN                       NaN           4.593593
# 164                     74.73                     78.16           0.507359
# 197                       NaN                       NaN           6.401056
# 230                     52.08                     71.74           4.190779
# 263                     62.80                     71.84           2.531088
# 296                     62.31                     71.13          14.914763
# 329                     56.55                     66.69           7.399461
#
#      mat_footprint_percap_tons
# 32                      1.1809
# 65                     11.7367
# 98                      8.7199
# 131                        NaN
# 164                     3.6568
# 197                        NaN
# 230                    14.4512
# 263                     7.3553
# 296                    26.9245
# 329                    27.9621
#
# [10 rows x 30 columns]

# %%
# Get the number of rows and columns from the dataset
rows, columns = hdi_2022_df.shape
print("Number of rows:", rows)
print("Number of columns:", columns)
# Out:
# Number of rows: 206
# Number of columns: 30

# %%
# Display the data type of each column in the 2022 dataset
hdi_2022_df.dtypes
# Out:
# Unnamed: 0                     int64
# iso3                          object
# country                       object
# year                           int64
# hdi                          float64
# life_expectancy              float64
# pop_millions                 float64
# hdi_f                        float64
# hdi_m                        float64
# life_expec_f                 float64
# life_expec_m                 float64
# expec_yr_school              float64
# expec_yr_school_f            float64
# expec_yr_school_m            float64
# mean_yr_school               float64
# mean_yr_school_f             float64
# mean_yr_school_m             float64
# gross_inc_percap             float64
# gross_inc_percap_f           float64
# gross_inc_percap_m           float64
# gender_development           float64
# gender_inequality            float64
# secondary_education_f_%      float64
# secondary_education_m_%      float64
# seats_in_parliament_f_%      float64
# seats_in_parliament_m_%      float64
# labour_participation_f_%     float64
# labour_participation_m_%     float64
# co2_emission_tons            float64
# mat_footprint_percap_tons    float64
# dtype: object

# %%
# Check for null values in each column of the dataset
missing_values = hdi_2022_df.isnull().sum()
missing_values
# Out:
# Unnamed: 0                    0
# iso3                          0
# country                       0
# year                          0
# hdi                           2
# life_expectancy               0
# pop_millions                  0
# hdi_f                        13
# hdi_m                        13
# life_expec_f                  0
# life_expec_m                  0
# expec_yr_school               1
# expec_yr_school_f             1
# expec_yr_school_m             1
# mean_yr_school                2
# mean_yr_school_f              2
# mean_yr_school_m              2
# gross_inc_percap              2
# gross_inc_percap_f           13
# gross_inc_percap_m           13
# gender_development           13
# gender_inequality            29
# secondary_education_f_%      17
# secondary_education_m_%      17
# seats_in_parliament_f_%       2
# seats_in_parliament_m_%       2
# labour_participation_f_%     12
# labour_participation_m_%     12
# co2_emission_tons             2
# mat_footprint_percap_tons    41
# dtype: int64

# %%
hdi_2022_df.dtypes
# Count the number of unique countries in the dataset
hdi_2022_df['country'].nunique()
# Out:
# 206

# %%
# This counts how many rows are repeated
hdi_2022_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Replace all – values in the dataset with pandas NA
hdi_2022_df = hdi_2022_df.replace("–", pd.NA)

# %%
# Convert the 'hdi' column to numeric values
# If there are any non-numeric values, they will become NaN
hdi_2022_df['hdi'] = pd.to_numeric(
    hdi_2022_df['hdi'], errors='coerce'
)
# Convert the 'gross_inc_percap' column to numeric values
# Non-numeric values will be converted to NaN
hdi_2022_df['gross_inc_percap'] = pd.to_numeric(
    hdi_2022_df['gross_inc_percap'], errors='coerce'
)

# %%
# Remove any duplicate rows from the dataset
# inplace=True makes the change directly in hdi_2022_df
hdi_2022_df.drop_duplicates(inplace=True)

# %%
# This ensures that only rows with valid HDI data are kept
hdi_2022_df.dropna(subset=['hdi'], inplace=True)

# %%
mean_hdi = hdi_2022_df['hdi'].mean()
median_hdi = hdi_2022_df['hdi'].median()
std_hdi = hdi_2022_df['hdi'].std()
mean_hdi, median_hdi, std_hdi
# Out:
# (np.float64(0.7228872549019609), 0.7395, 0.15302880386427825)

# %%
# idxmax() gives the index of the maximum HDI
highest_hdi_country = hdi_2022_df.loc[
    hdi_2022_df['hdi'].idxmax(), ['country', 'hdi']
]
highest_hdi_country
# Out:
# country    Switzerland
# hdi              0.967
# Name: 5609, dtype: object

# %%
# idxmin() gives the index of the minimum HDI
lowest_hdi_country = hdi_2022_df.loc[
    hdi_2022_df['hdi'].idxmin(), ['country', 'hdi']
]
lowest_hdi_country
# Out:
# country    Somalia
# hdi           0.38
# Name: 5345, dtype: object

# %%
# Filter the dataset to include only countries with HDI greater than 0.800
# Sort these high-HDI countries by 'gross_inc_percap' in descending order
high_hdi_df = hdi_2022_df[hdi_2022_df['hdi'] > 0.800]
high_hdi_sorted_df = high_hdi_df.sort_values(
    by='gross_inc_percap',
    ascending=False
)
high_hdi_sorted_df[['country', 'hdi', 'gross_inc_percap']].head(10)
# Out:
#                      country    hdi  gross_inc_percap
# 3332           Liechtenstein  0.942      146673.24150
# 4718                   Qatar  0.875       95944.37754
# 5213               Singapore  0.949       88761.14559
# 2705                 Ireland  0.950       87467.51391
# 3398              Luxembourg  0.927       78554.23640
# 6104    United Arab Emirates  0.937       74103.71494
# 5609             Switzerland  0.967       69432.78669
# 4322                  Norway  0.966       69189.76165
# 6170           United States  0.927       65564.93798
# 2474  Hong Kong, China (SAR)  0.956       62485.50516

# %%
def classify_hdi(hdi):
    if hdi < 0.550:
        return "Low"
    elif 0.550 <= hdi <= 0.699:
        return "Medium"
    elif 0.700 <= hdi <= 0.799:
        return "High"
    else:
        return "Very High"
# Apply the function to the 'hdi' column and create a new column 'HDI Category'
hdi_2022_df['HDI Category'] = hdi_2022_df['hdi'].apply(classify_hdi)
hdi_2022_df.head()
# Out:
#      Unnamed: 0 iso3      country  year    hdi  life_expectancy  pop_millions  \
# 32           33  AFG  Afghanistan  2022  0.462           62.879     41.128771
# 65           66  ALB      Albania  2022  0.789           76.833      2.842321
# 98           99  DZA      Algeria  2022  0.745           77.129     44.903225
# 131         132  AND      Andorra  2022  0.884           83.552      0.079824
# 164         165  AGO       Angola  2022  0.591           61.929     35.588987
#
#         hdi_f     hdi_m  life_expec_f  ...  gender_inequality  \
# 32   0.332443  0.534145        66.213  ...              0.665
# 65   0.780277  0.798432        79.472  ...              0.116
# 98   0.681844  0.773800        78.457  ...              0.460
# 131       NaN       NaN        85.838  ...                NaN
# 164  0.560890  0.619680        64.541  ...              0.520
#
#      secondary_education_f_%  secondary_education_m_%  \
# 32                  7.042050                24.077040
# 65                 82.249185                86.476634
# 98                 42.910456                46.815170
# 131                81.718277                84.599998
# 164                21.339865                37.411946
#
#      seats_in_parliament_f_%  seats_in_parliament_m_%  \
# 32                 27.215190                72.784810
# 65                 35.714286                64.285714
# 98                  7.005254                92.994746
# 131                46.428571                53.571429
# 164                33.636364                66.363636
#
#      labour_participation_f_%  labour_participation_m_%  co2_emission_tons  \
# 32                      23.33                     77.09           0.306318
# 65                      56.08                     69.91           1.717758
# 98                      17.57                     65.53           4.079540
# 131                       NaN                       NaN           4.593593
# 164                     74.73                     78.16           0.507359
#
#      mat_footprint_percap_tons  HDI Category
# 32                      1.1809           Low
# 65                     11.7367          High
# 98                      8.7199          High
# 131                        NaN     Very High
# 164                     3.6568        Medium
#
# [5 rows x 31 columns]

# %%
# Count how many countries fall into each HDI category
hdi_2022_df['HDI Category'].value_counts()
# Out:
# HDI Category
# Very High    71
# High         54
# Medium       44
# Low          35
# Name: count, dtype: int64

# %%
# Display all column names of the 2022 dataset
hdi_2022_df.columns
# Out:
# Index(['Unnamed: 0', 'iso3', 'country', 'year', 'hdi', 'life_expectancy',
#        'pop_millions', 'hdi_f', 'hdi_m', 'life_expec_f', 'life_expec_m',
#        'expec_yr_school', 'expec_yr_school_f', 'expec_yr_school_m',
#        'mean_yr_school', 'mean_yr_school_f', 'mean_yr_school_m',
#        'gross_inc_percap', 'gross_inc_percap_f', 'gross_inc_percap_m',
#        'gender_development', 'gender_inequality', 'secondary_education_f_%',
#        'secondary_education_m_%', 'seats_in_parliament_f_%',
#        'seats_in_parliament_m_%', 'labour_participation_f_%',
#        'labour_participation_m_%', 'co2_emission_tons',
#        'mat_footprint_percap_tons', 'HDI Category'],
#       dtype='object')

# %%
# Save the updated dataset to a new CSV file
hdi_2022_df.to_csv("HDI_category_added.csv", index=False)

# %% [markdown]
# Problem - 1B - HDI Visualization and Trend Analysis (2020 – 2022)

# %%
# Filter the dataset to include only rows where the year is 2020, 2021, or 2022
hdi_problem1B_df =df[df['year'].isin([2020, 2021, 2022])]
hdi_problem1B_df.to_csv("HDI_problem1B.csv", index=False)

# %%
missing_values = hdi_problem1B_df[['hdi', 'country', 'year']].isnull().sum()
missing_values
# Out:
# hdi        8
# country    0
# year       0
# dtype: int64

# %%
hdi_problem1B_df = hdi_problem1B_df.replace("–", pd.NA)

# %%
hdi_problem1B_df['hdi'] = pd.to_numeric(
    # If there are any non-numeric values, they will become NaN
    hdi_problem1B_df['hdi'], errors='coerce'
)

# %%
# Remove rows where 'hdi', 'country', or 'year' has missing values (NaN)
hdi_problem1B_df.dropna(
    subset=['hdi', 'country', 'year'],
    inplace=True
)

# %%
hdi_problem1B_df.drop_duplicates(inplace=True)

# %%
# .str.strip() removes extra spaces before and after the names
# .str.title() converts names to title case
hdi_problem1B_df['country'] = (
    hdi_problem1B_df['country']
    .str.strip()
    .str.title()
)

# %%
# This includes number of rows, columns, data types, and non-null counts
hdi_problem1B_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 610 entries, 30 to 6797
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 610 non-null    int64
#  1   iso3                       610 non-null    object
#  2   country                    610 non-null    object
#  3   year                       610 non-null    int64
#  4   hdi                        610 non-null    float64
#  5   life_expectancy            610 non-null    float64
#  6   pop_millions               610 non-null    float64
#  7   hdi_f                      577 non-null    float64
#  8   hdi_m                      577 non-null    float64
#  9   life_expec_f               610 non-null    float64
#  10  life_expec_m               610 non-null    float64
#  11  expec_yr_school            610 non-null    float64
#  12  expec_yr_school_f          610 non-null    float64
#  13  expec_yr_school_m          610 non-null    float64
#  14  mean_yr_school             610 non-null    float64
#  15  mean_yr_school_f           610 non-null    float64
#  16  mean_yr_school_m           610 non-null    float64
#  17  gross_inc_percap           610 non-null    float64
#  18  gross_inc_percap_f         577 non-null    float64
#  19  gross_inc_percap_m         577 non-null    float64
#  20  gender_development         577 non-null    float64
#  21  gender_inequality          529 non-null    float64
#  22  secondary_education_f_%    565 non-null    float64
#  23  secondary_education_m_%    565 non-null    float64
#  24  seats_in_parliament_f_%    604 non-null    float64
#  25  seats_in_parliament_m_%    604 non-null    float64
#  26  labour_participation_f_%   577 non-null    float64
#  27  labour_participation_m_%   577 non-null    float64
#  28  co2_emission_tons          607 non-null    float64
#  29  mat_footprint_percap_tons  493 non-null    float64
# dtypes: float64(26), int64(2), object(2)
# memory usage: 147.7+ KB

# %%
selected_countries = [
    'Nepal',
    'India',
    'China',
    'United States',
    'Norway'
]

# %%
# Filter the dataset to include only the countries listed in selected_countries
# This creates a new dataset with data for only those specific countries
country_hdi_df = hdi_problem1B_df[
    hdi_problem1B_df['country'].isin(selected_countries)
]

# %%
plt.figure(figsize=(8, 5))
# Loop through each selected country to plot its HDI trend
for country in selected_countries:
    country_data = country_hdi_df[
        country_hdi_df['country'] == country
    ]
    plt.plot(
        country_data['year'],
        country_data['hdi'],
        marker='o',
        label=country
    )

plt.xlabel("Year")
plt.ylabel("Human Development Index (HDI)")
plt.title("HDI Trend (2020–2022) for Selected Countries")
plt.legend(title="Country")
plt.grid(True)
plt.show()

# %% [markdown]
# Figure 1

# %%
# Group the dataset by 'year' and calculate the average HDI for each year
year_avg = hdi_problem1B_df.groupby('year')['hdi'].mean().reset_index()
year_avg
# Out:
#    year       hdi
# 0  2020  0.720897
# 1  2021  0.720039
# 2  2022  0.722887

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.bar(year_avg['year'], year_avg['hdi'], color='lightgreen')  # changed color
plt.xlabel("Year")
plt.ylabel("Average HDI")
plt.title(" (2020–2022) Average HDI Across Years")
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# Figure 2

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.boxplot(
    [hdi_problem1B_df[hdi_problem1B_df['year']==y]['hdi'] for y in [2020, 2021, 2022]],
    labels=[2020, 2021, 2022],
    patch_artist=True,  # allows filling color
    boxprops=dict(facecolor='lightcoral', color='red'),  # box color and border color
    medianprops=dict(color='yellow')  # median line color
)
plt.xlabel("Year")
plt.ylabel("HDI Value")
plt.title("2020–2022 HDI Distribution for ")
plt.show()
# Out:
# /tmp/ipython-input-2969893940.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %% [markdown]
# Figure 3

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.scatter(
    hdi_problem1B_df['gross_inc_percap'],
    hdi_problem1B_df['hdi'],
    color='blue',  # changed color
    alpha=0.6
)
plt.xlabel("GNI per Capita")
plt.ylabel("HDI Value")
plt.title("(2020–2022) HDI vs GNI per Capita ")
plt.show()

# %% [markdown]
# Figure 4

# %% [markdown]
# Problem 2
# Advanced HDI Exploration

# %%
south_asia_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

# %%
hdi_southasia_df = hdi_problem1B_df[
    hdi_problem1B_df['country'].isin(south_asia_countries)
]

# %%
hdi_southasia_df.to_csv("HDI_SouthAsia.csv", index=False)

# %%
hdi_southasia_df['life_expectancy'] = pd.to_numeric(hdi_southasia_df['life_expectancy'], errors='coerce')
hdi_southasia_df['gross_inc_percap'] = pd.to_numeric(hdi_southasia_df['gross_inc_percap'], errors='coerce')
# Out:
# /tmp/ipython-input-1876199044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdi_southasia_df['life_expectancy'] = pd.to_numeric(hdi_southasia_df['life_expectancy'], errors='coerce')
# /tmp/ipython-input-1876199044.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdi_southasia_df['gross_inc_percap'] = pd.to_numeric(hdi_southasia_df['gross_inc_percap'], errors='coerce')

# %%
hdi_southasia_df.dropna(
    subset=['life_expectancy', 'gross_inc_percap'],
    inplace=True
)
# Out:
# /tmp/ipython-input-3972144292.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdi_southasia_df.dropna(

# %%
# Aggregate by country (mean across all years)
southasia_country_df = (
    hdi_southasia_df
    .groupby('country', as_index=False)
    .agg({
        'life_expectancy': 'mean',
        'gross_inc_percap': 'mean',
        'hdi': 'mean'
    })
)

# %%
# Calculate a new 'Composite Score' for South Asian countries
# It is 30% of life expectancy + 30% of gross income per capita
southasia_country_df['Composite Score'] = (
    0.30 * southasia_country_df['life_expectancy'] +
    0.30 * southasia_country_df['gross_inc_percap']
)

southasia_country_df['Composite Rank'] = (
    southasia_country_df['Composite Score']
    .rank(ascending=False, method='dense')
)

composite_rank_df = southasia_country_df.sort_values('Composite Rank')

# %%
top5_composite = composite_rank_df.head(5)

top5_composite[['country', 'Composite Score', 'hdi']]
# Out:
#       country  Composite Score       hdi
# 4    Maldives      4827.657597  0.750667
# 7   Sri Lanka      3767.752918  0.780000
# 2      Bhutan      3097.787317  0.677667
# 3       India      1978.776712  0.638333
# 1  Bangladesh      1877.251264  0.663000

# %%
import matplotlib.pyplot as plt

plt.barh(
    top5_composite['country'],
    top5_composite['Composite Score'],
    color='orange'  # changed color
)
plt.xlabel("Composite Development Score")
plt.ylabel("Country")
plt.title("Top 5 South Asian Countries by Composite Score")
plt.show()

# %% [markdown]
# Figure 5

# %%
hdi_rank_df = hdi_southasia_df.sort_values(by='hdi',ascending=False)
hdi_rank_df[['country', 'hdi']]
# Out:
#           country    hdi
# 5476    Sri Lanka  0.783
# 5477    Sri Lanka  0.780
# 5475    Sri Lanka  0.777
# 3530     Maldives  0.762
# 3529     Maldives  0.753
# 3528     Maldives  0.737
# 659        Bhutan  0.681
# 658        Bhutan  0.677
# 657        Bhutan  0.675
# 461    Bangladesh  0.670
# 460    Bangladesh  0.662
# 459    Bangladesh  0.657
# 2573        India  0.644
# 2571        India  0.638
# 2572        India  0.633
# 4091        Nepal  0.601
# 4089        Nepal  0.593
# 4090        Nepal  0.591
# 4388     Pakistan  0.540
# 4387     Pakistan  0.537
# 4386     Pakistan  0.536
# 30    Afghanistan  0.488
# 31    Afghanistan  0.473
# 32    Afghanistan  0.462

# %%
#Calculate the first and second quartile (25th percentile and 75 percentile) of HDI
Q1_hdi = hdi_southasia_df['hdi'].quantile(0.25)
Q3_hdi = hdi_southasia_df['hdi'].quantile(0.75)
IQR_hdi = Q3_hdi - Q1_hdi

hdi_lower = Q1_hdi - 1.5 * IQR_hdi
hdi_upper = Q3_hdi + 1.5 * IQR_hdi

# %%
Q1_gni = hdi_southasia_df['gross_inc_percap'].quantile(0.25)
Q3_gni = hdi_southasia_df['gross_inc_percap'].quantile(0.75)
IQR_gni = Q3_gni - Q1_gni

gni_lower = Q1_gni - 1.5 * IQR_gni
gni_upper = Q3_gni + 1.5 * IQR_gni

# %%
hdi_southasia_df['HDI_Outlier'] = (
    (hdi_southasia_df['hdi'] < hdi_lower) |
    (hdi_southasia_df['hdi'] > hdi_upper)
)

hdi_southasia_df['GNI_Outlier'] = (
    (hdi_southasia_df['gross_inc_percap'] < gni_lower) |
    (hdi_southasia_df['gross_inc_percap'] > gni_upper)
)
# Out:
# /tmp/ipython-input-2205920403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdi_southasia_df['HDI_Outlier'] = (
# /tmp/ipython-input-2205920403.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdi_southasia_df['GNI_Outlier'] = (

# %%
# Select rows that are NOT outliers in HDI or GNI
normal = hdi_southasia_df[~(hdi_southasia_df['HDI_Outlier'] | hdi_southasia_df['GNI_Outlier'])]
plt.scatter(normal['gross_inc_percap'], normal['hdi'], color='green', alpha=0.6, label='Normal')
# Select rows that ARE outliers in HDI or GNI
outliers = hdi_southasia_df[hdi_southasia_df['HDI_Outlier'] | hdi_southasia_df['GNI_Outlier']]
plt.scatter(outliers['gross_inc_percap'], outliers['hdi'], color='red', alpha=0.8, label='Outliers')

plt.xlabel('GNI per Capita')
plt.ylabel('HDI')
plt.title('GNI per Capita vs HDI with Outliers (South Asia)')
plt.legend()
plt.show()

# %% [markdown]
# Figure 6

# %%
# Display the outlier rows with selected columns: country, year, HDI, and GNI per capita
outliers[['country', 'year', 'hdi', 'gross_inc_percap']]
# Out:
# Empty DataFrame
# Columns: [country, year, hdi, gross_inc_percap]
# Index: []

# %%
hdi_southasia_df['gender_development'] = pd.to_numeric(
hdi_southasia_df['gender_development'], errors='coerce'
)

hdi_southasia_df['life_expectancy'] = pd.to_numeric(
    hdi_southasia_df['life_expectancy'], errors='coerce'
)

hdi_southasia_df['hdi'] = pd.to_numeric(
    hdi_southasia_df['hdi'], errors='coerce'
)
# Out:
# /tmp/ipython-input-1758464440.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdi_southasia_df['gender_development'] = pd.to_numeric(
# /tmp/ipython-input-1758464440.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdi_southasia_df['life_expectancy'] = pd.to_numeric(
# /tmp/ipython-input-1758464440.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdi_southasia_df['hdi'] = pd.to_numeric(

# %%
hdi_clean = hdi_southasia_df.dropna(subset=['gender_development', 'life_expectancy', 'hdi'])

# %%
corr_gender = hdi_clean['gender_development'].corr(hdi_clean['hdi'])
corr_life = hdi_clean['life_expectancy'].corr(hdi_clean['hdi'])

print("Pearson correlation between Gender Development Index and HDI:", corr_gender)
print("Pearson correlation between Life Expectancy Index and HDI:", corr_life)
# Out:
# Pearson correlation between Gender Development Index and HDI: 0.8742177004831327
# Pearson correlation between Life Expectancy Index and HDI: 0.9387641385416623

# %%
import numpy as np
import matplotlib.pyplot as plt

x = hdi_clean['gender_development']
y = hdi_clean['hdi']

plt.figure(figsize=(7,5))
# Scatter points
plt.scatter(x, y, color='blue', label='Countries', s=60, alpha=0.7, edgecolor='k')

# Fit a linear trendline
m, c = np.polyfit(x, y, 1)
plt.plot(x, m*x + c, color='green', linewidth=2, label='Trendline')

plt.title('Gender Development Index vs HDI')
plt.xlabel('Gender Development Index')
plt.ylabel('HDI')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# Figure 7

# %%
x2 = hdi_clean['life_expectancy']
y2 = hdi_clean['hdi']
plt.scatter(x2, y2, color='blue', label='Countries')
m2, c2 = np.polyfit(x2, y2, 1)
# Fit a linear trendline (y = m*x + c) using numpy's polyfit
plt.plot(x2, m2*x2 + c2, color='red', label='Trendline')
plt.title('Life Expectancy vs HDI')
plt.xlabel('Life Expectancy')
plt.ylabel('HDI')
plt.legend()
plt.show()

# %% [markdown]
# Figure 8

# %%
hdi_southasia_df['gross_inc_percap'] = pd.to_numeric(
    hdi_southasia_df['gross_inc_percap'], errors='coerce'
)
hdi_southasia_df['hdi'] = pd.to_numeric(
    hdi_southasia_df['hdi'], errors='coerce'
)
# Out:
# /tmp/ipython-input-1983459760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdi_southasia_df['gross_inc_percap'] = pd.to_numeric(
# /tmp/ipython-input-1983459760.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hdi_southasia_df['hdi'] = pd.to_numeric(

# %%
hdi_southasia_clean = hdi_southasia_df.dropna(subset=['gross_inc_percap', 'hdi'])
southasia_country = (
    hdi_southasia_clean
    .groupby('country', as_index=False)
    .agg({'gross_inc_percap':'mean', 'hdi':'mean'})
)

# %%
southasia_country['GNI_HDI_Gap'] = southasia_country['gross_inc_percap'] - southasia_country['hdi']

# %%
top_positive_gap = southasia_country.sort_values(
    by='GNI_HDI_Gap', ascending=False
).head(3)

top_positive_gap[['country', 'GNI_HDI_Gap']]
# Out:
#      country   GNI_HDI_Gap
# 4   Maldives  16011.230657
# 7  Sri Lanka  12481.929060
# 2     Bhutan  10253.395723

# %%
top_negative_gap = southasia_country.sort_values(
    by='GNI_HDI_Gap', ascending=True
).head(3)

top_negative_gap[['country', 'GNI_HDI_Gap']]
# Out:
#        country  GNI_HDI_Gap
# 0  Afghanistan  1618.240627
# 5        Nepal  3901.138692
# 6     Pakistan  5149.963106

# %%
gap_plot = pd.concat([top_positive_gap, top_negative_gap])
colors = ['blue']*3 + ['red']*3
plt.figure(figsize=(8,5))
plt.bar(gap_plot['country'], gap_plot['GNI_HDI_Gap'], color=colors)
plt.xlabel('GNI HDI Gap')
plt.ylabel('Country')
plt.title('Top 3 Positive and Negative GNI HDI Gaps (South Asia)')
plt.show()

# %% [markdown]
# Figure 9

# %%
gap_plot[['country', 'GNI_HDI_Gap']]
# Out:
#        country   GNI_HDI_Gap
# 4     Maldives  16011.230657
# 7    Sri Lanka  12481.929060
# 2       Bhutan  10253.395723
# 0  Afghanistan   1618.240627
# 5        Nepal   3901.138692
# 6     Pakistan   5149.963106

# %% [markdown]
# Problem 3
# Comparative Regional Analysis: South Asia vs Middle East

# %%
hdi_problem1B_df = pd.read_csv("HDI_problem1B.csv")

# %%
south_asia_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
                        "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan",
                         "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar",
                         "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

# %%
hdi_southasia_df = hdi_problem1B_df[hdi_problem1B_df['country'].isin(south_asia_countries)]

hdi_middleeast_df = hdi_problem1B_df[hdi_problem1B_df['country'].isin(middle_east_countries)]

# %%
hdi_southasia_df.to_csv("HDI_SouthAsia_2020_2022.csv", index=False)
hdi_middleeast_df.to_csv("HDI_MiddleEast_2020_2022.csv", index=False)

# %%
hdi_southasia_df = pd.read_csv("HDI_SouthAsia_2020_2022.csv")
hdi_middleeast_df = pd.read_csv("HDI_MiddleEast_2020_2022.csv")

# %%
hdi_southasia_df['hdi'] = pd.to_numeric(hdi_southasia_df['hdi'], errors='coerce')
hdi_middleeast_df['hdi'] = pd.to_numeric(hdi_middleeast_df['hdi'], errors='coerce')

# %%
hdi_southasia_df = hdi_southasia_df.dropna(subset=['hdi'])
hdi_middleeast_df = hdi_middleeast_df.dropna(subset=['hdi'])

# %%
southasia_agg = hdi_southasia_df.groupby('country', as_index=False)['hdi'].mean()
middleeast_agg = hdi_middleeast_df.groupby('country', as_index=False)['hdi'].mean()

# Compute mean and std dev for descriptive stats
mean_southasia = southasia_agg['hdi'].mean()
std_southasia = southasia_agg['hdi'].std()
mean_middleeast = middleeast_agg['hdi'].mean()
std_middleeast = middleeast_agg['hdi'].std()

print("South Asia HDI (2020-2022) Mean:", round(mean_southasia, 3), ", Std Dev:", round(std_southasia, 3))
print("Middle East HDI (2020-2022) Mean:", round(mean_middleeast, 3), ", Std Dev:", round(std_middleeast, 3))
# Out:
# South Asia HDI (2020-2022) Mean: 0.64 , Std Dev: 0.103
# Middle East HDI (2020-2022) Mean: 0.789 , Std Dev: 0.146

# %%
# Top 3 and bottom 3 countries per region
top3_southasia = southasia_agg.nlargest(3, 'hdi')
bottom3_southasia = southasia_agg.nsmallest(3, 'hdi')

top3_middleeast = middleeast_agg.nlargest(3, 'hdi')
bottom3_middleeast = middleeast_agg.nsmallest(3, 'hdi')

# %%
# Add region column for plotting
top3_southasia['Region'] = 'South Asia'
bottom3_southasia['Region'] = 'South Asia'
top3_middleeast['Region'] = 'Middle East'
bottom3_middleeast['Region'] = 'Middle East'

# %%
plot_df = pd.concat([top3_southasia, bottom3_southasia, top3_middleeast, bottom3_middleeast])

# Assign colors: green for South Asia, red for Middle East
colors = ['blue' if r == 'South Asia' else 'red' for r in plot_df['Region']]

# Simple bar chart
plt.bar(plot_df['country'], plot_df['hdi'], color=colors)
plt.ylabel('Average HDI (2020-2022)')
plt.title('Top and Bottom 3 HDI Performers: South Asia vs Middle East')

# Rotate country names vertically
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# Figure 10

# %%
metrics = ['gender_development', 'life_expectancy', 'gross_inc_percap']
# Convert the metrics to numeric values
for metric in metrics:
    hdi_southasia_df[metric] = pd.to_numeric(hdi_southasia_df[metric], errors='coerce')
    hdi_middleeast_df[metric] = pd.to_numeric(hdi_middleeast_df[metric], errors='coerce')
# Remove rows with missing values in any of the metrics for South Asia
hdi_southasia_clean = hdi_southasia_df.dropna(subset=metrics)
# Remove rows with missing values in any of the metrics for Middle East
hdi_middleeast_clean = hdi_middleeast_df.dropna(subset=metrics)

# %%
avg_southasia = hdi_southasia_clean[metrics].mean()
avg_middleeast = hdi_middleeast_clean[metrics].mean()

comparison_df = pd.DataFrame({
    'Metric': metrics,
    'South Asia': avg_southasia.values,
    'Middle East': avg_middleeast.values
})

comparison_df
# Out:
#                Metric   South Asia   Middle East
# 0  gender_development     0.881458      0.896545
# 1     life_expectancy    70.970083     75.855455
# 2    gross_inc_percap  7766.509931  37750.770520

# %%
x = np.arange(len(metrics))
width = 0.35
plt.bar(x - width/2, comparison_df['South Asia'], width, label='South Asia', color='blue')
plt.bar(x + width/2, comparison_df['Middle East'], width, label='Middle East', color='red')
plt.xticks(x, comparison_df['Metric'])
plt.ylabel('Average Value')
plt.title('Comparison of HDI Metrics: South Asia vs Middle East')
plt.legend()
plt.show()

# %% [markdown]
# Figure 11

# %%
range_southasia = hdi_southasia_df['hdi'].max() - hdi_southasia_df['hdi'].min()
range_middleeast = hdi_middleeast_df['hdi'].max() - hdi_middleeast_df['hdi'].min()
# Print the HDI range rounded to 3 decimal places
print("South Asia HDI Range:", round(range_southasia, 3))
print("Middle East HDI Range:", round(range_middleeast, 3))
# Out:
# South Asia HDI Range: 0.321
# Middle East HDI Range: 0.513

# %%
cv_southasia = hdi_southasia_df['hdi'].std() / hdi_southasia_df['hdi'].mean()
cv_middleeast = hdi_middleeast_df['hdi'].std() / hdi_middleeast_df['hdi'].mean()

print("South Asia CV:", round(cv_southasia, 3))
print("Middle East CV:", round(cv_middleeast, 3))
# Out:
# South Asia CV: 0.154
# Middle East CV: 0.179

# %%
if cv_southasia > cv_middleeast:
    print("South Asia shows more variation in HDI.")
else:
    print("Middle East shows more variation in HDI.")
# Out:
# Middle East shows more variation in HDI.

# %%
corr_sa_gender = hdi_southasia_clean['gender_development'].corr(
    hdi_southasia_clean['hdi']
)

corr_sa_life = hdi_southasia_clean['life_expectancy'].corr(
    hdi_southasia_clean['hdi']
)

print("South Asia:")
print("Gender Development vs HDI:", round(corr_sa_gender, 3))
print("Life Expectancy vs HDI:", round(corr_sa_life, 3))
# Out:
# South Asia:
# Gender Development vs HDI: 0.874
# Life Expectancy vs HDI: 0.939

# %%
corr_me_gender = hdi_middleeast_clean['gender_development'].corr(
    hdi_middleeast_clean['hdi']
)

corr_me_life = hdi_middleeast_clean['life_expectancy'].corr(
    hdi_middleeast_clean['hdi']
)

print("Middle East:")
print("Gender Development vs HDI:", round(corr_me_gender, 3))
print("Life Expectancy vs HDI:", round(corr_me_life, 3))
# Out:
# Middle East:
# Gender Development vs HDI: 0.936
# Life Expectancy vs HDI: 0.933

# %%
x = hdi_southasia_clean['gender_development']
y = hdi_southasia_clean['hdi']

plt.scatter(x, y, alpha=0.6)
m, c = np.polyfit(x, y, 1)
plt.plot(x, m*x + c, color='green')

plt.xlabel("Gender Development Index")
plt.ylabel("HDI")
plt.title("South Asia: Gender Development vs HDI")
plt.show()

# %% [markdown]
# Figure 12

# %%
x = hdi_southasia_clean['life_expectancy']
y = hdi_southasia_clean['hdi']

plt.scatter(x, y, alpha=0.6)
# Fit a linear trendline (y = m*x + b) using numpy's polyfit
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red')

plt.xlabel("Life Expectancy Index")
plt.ylabel("HDI")
plt.title("South Asia: Life Expectancy vs HDI")
plt.show()

# %% [markdown]
# Figure 13

# %%
# 3.9 Task 7: Outlier Detection Using 1.5 × IQR Rule
def detect_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    return (series < Q1 - 1.5*IQR) | (series > Q3 + 1.5*IQR)

# Flag outliers in HDI or GNI per Capita for each region
hdi_southasia_df['Outlier'] = detect_outliers(hdi_southasia_df['hdi']) | \
                               detect_outliers(hdi_southasia_df['gross_inc_percap'])

hdi_middleeast_df['Outlier'] = detect_outliers(hdi_middleeast_df['hdi']) | \
                               detect_outliers(hdi_middleeast_df['gross_inc_percap'])

# Scatter plot highlighting all points (outliers will be flagged separately)
plt.figure(figsize=(8,6))
plt.scatter(hdi_southasia_df['gross_inc_percap'], hdi_southasia_df['hdi'],
            label="South Asia", alpha=0.6)
plt.scatter(hdi_middleeast_df['gross_inc_percap'], hdi_middleeast_df['hdi'],
            label="Middle East", alpha=0.6)

plt.xlabel("GNI per Capita")
plt.ylabel("HDI")
plt.title("Outliers in HDI vs GNI per Capita")
plt.legend()
plt.show()

# %% [markdown]
# Figure 14
